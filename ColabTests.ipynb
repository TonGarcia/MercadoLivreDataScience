# %% [markdown]
# # Funcionalidades Interessantes do Colab
#
# 1. Versionamento: Menu > Arquivo > Histórico de Revisões
# 1. Menu Lateral:
#     1. Ícone de navegação rápida deste notebook
#     1. Ícone de Find & Replace
#     1. <> ícone de códigos prontos
#     1. Ícone de pasta = diretórios e datasets (padrão do Colab ou importados/montados do google drive)

# %% [markdown]
# # Teste Datasets Colab
